# %% [markdown]
# #Q.1 Login to your Instagram Handle
# Submit with sample username and password

# %%
#OPENING THE CHROMEDRIVER:

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
driver=webdriver.Chrome(service=Service('/Users/rishismac/Downloads/chromedriver_mac_arm64'))

# %%
#LOGING INTO INSTAGRAM ACCOUNT:

def login(username,password):
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC
    wait=WebDriverWait(driver,200)
    #OPENING THE WEB PAGE:
    driver.get('https://www.instagram.com/')
    
    #FETCHING THE USERNAME BOX AND TYPING CREDENTIALS:
    username_box=wait.until(EC.presence_of_element_located((By.NAME,'username')))
    username_box.click()
    username_box.send_keys(username)
    
    #FETCHING THE PASSWORD BOX AND TTYPING PASSWORD:
    password_box=driver.find_element(By.NAME,'password')
    password_box.click()
    password_box.send_keys(password)
    
    #CLICKING ON LOGIN BUTTON:
    login=driver.find_element(By.XPATH,'//button')
    login.submit()
    
    
    #HANDLING THE REMEMBER CREDENTIAL POP UP:
    notnow_save_cred=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="_ac8f"]/div[@role="button"]')))
    notnow_save_cred.click()
    2
    #HANDLING THE NOTIFICATION POP UP:
    notnow_notifications=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="_a9-z"]/button[@class="_a9-- _a9_1"]')))
    notnow_notifications.click()
    driver.maximize_window()

# %%
login('saptarshi_9112','India@123456')

# %%
def home():
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC
    wait=WebDriverWait(driver,100)
    
    
    #finding the home button and clicking:
    home=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="x1n2onr6"]//a')))
    home.click()
    driver.implicitly_wait(50)

# %%
home()

# %% [markdown]
# Q.2 Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”
# Note : Make sure to avoid printing hashtags

# %%
def search_content(keyword):
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC
    wait=WebDriverWait(driver,100)
    
    #Fetching the search button and clicking on it:
    search=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="x1n2onr6"]//div[@class="_aacl _aacp _aacu _aacx _aada"]')))
    search.click()
    
    #Entering keyword in search box:
    search_box=wait.until(EC.presence_of_element_located((By.XPATH,'//input[@placeholder="Search"]')))
    search_box.send_keys(keyword)
    
    #Extracting list of all suggestions:
    li=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@role="none"]//div[@class="x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1uhb9sk x1plvlek xryxfnj x1iyjqo2 x2lwn1j xeuugli xdt5ytf xqjyukv x1cy8zhl x1oa3qoh x1nhvcw1"]')))
    lis=driver.find_elements(By.XPATH,'//div[@role="none"]//div[@class="x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1uhb9sk x1plvlek xryxfnj x1iyjqo2 x2lwn1j xeuugli xdt5ytf xqjyukv x1cy8zhl x1oa3qoh x1nhvcw1"]')
    for i in lis:
        #Removing hastags if present:
        if '#' in i.text:
            li=i.text[1:].split()
            print(li[0])
        else:
            li=i.text.split()
            print(li[0])

# %%
search_content('food')
# Out:
# adis_food_voyage
# foodtalkindia
# the_bong_gastronomist
# dilsefoodie
# food.darzee
# food_blogger290
# food
# foodish_punekar
# get_me_food_
# foodie_incarnate
# bongeats
# yourfoodlab
# food.junkie.kolkata
# pune_food_blogger
# mummymealspune
# foodiebliss09
# foodiepreneur
# punefoodstation
# hungrysimonlovesfood
# food_love_foodie
# foodie.soulmates
# food
# lakshya__singh
# punefoodiesoul
# food.spotted
# foodie.vaishnavijadhav
# pune_artkitchen
# food52
# thepunefoodie
# paris.explore
# foodrad
# bangalorefoodiee
# foodies_tales
# thesassysasha
# italyexplores
# food_faujiz
# foodie
# foodsta717
# foodconnectindia
# fork_spoon_pune
# foodporn
# foodie_yaaaaashu
# tasteofmiles
# roamingferalcat
# _foodtravelfashion
# delhifoodwalks
# foodblogger
# jaipur_blogger
# foodchoiceofmumbai
# tasty_pune
# Food
# food_fanatic_jaipur
# foodhuntingmyway
# foodhallindia
# Food
# food.gineer

# %% [markdown]
# Q.3. Searching and Opening a profile using
# Open profile of “So Delhi”

# %%
def visit_page(keyword):
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC
    wait=WebDriverWait(driver,200)
    
    #:FETCHING THE SEARCH BOX AND TYPING KEYWORD
    search=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="x1n2onr6"]//div[@class="_aacl _aacp _aacu _aacx _aada"]')))
    search.click()
    
    search_box=wait.until(EC.presence_of_element_located((By.XPATH,'//input[@placeholder="Search"]')))
    search_box.send_keys(keyword)
    
    #CLICKING ON DESIRED ELEMENT:
    element=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@role="none"]')))
    element.click()

# %%
visit_page('So Delhi')

# %%
Q.4. Follow/Unfollow given handle - 
Open the Instagram Handle of “So Delhi”
Start following it. Print a message if you are already following
After following, unfollow the instagram handle. Print a message if you have already unfollowed.

# %%
def follow_unfollow():
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC
    wait=WebDriverWait(driver,100)
    driver.maximize_window()
    
    #FETCHING THE FOLLOW BUTTON AND CLICKING IT:
    follow=wait.until(EC.presence_of_element_located((By.XPATH,'//button[@class="_acan _acap _acas _aj1-"]')))
    follow.click()
    print('Already following')
    follow.click()
    
    #WAITING FOR PAGE TO LOAD:
    driver.implicitly_wait(30)
    
    #CLICKING ON FOLLOWING BUTTON AND CLICKING ON UNFOLLOW:
    lis=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="x1i10hfl x1qjc9v5 xjbqb8w xjqpnuy xa49m3k xqeqjp1 x2hbi6w x13fuv20 xu3j5b3 x1q0q8m5 x26u7qi x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xdl72j9 x2lah0s xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r x2lwn1j xeuugli xexx8yu x4uap5 x18d9i69 xkhd6sd x1n2onr6 x16tdsg8 x1hl2dhg xggy1nq x1ja2u2z x1t137rt x1q0g3np x87ps6o x1lku1pv x1a2a7pz xh8yej3 x193iq5w x1lliihq x1dm5mii x16mil14 xiojian x1yutycm"]')))
    li=driver.find_elements(By.XPATH,'//div[@class="x1i10hfl x1qjc9v5 xjbqb8w xjqpnuy xa49m3k xqeqjp1 x2hbi6w x13fuv20 xu3j5b3 x1q0q8m5 x26u7qi x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xdl72j9 x2lah0s xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r x2lwn1j xeuugli xexx8yu x4uap5 x18d9i69 xkhd6sd x1n2onr6 x16tdsg8 x1hl2dhg xggy1nq x1ja2u2z x1t137rt x1q0g3np x87ps6o x1lku1pv x1a2a7pz xh8yej3 x193iq5w x1lliihq x1dm5mii x16mil14 xiojian x1yutycm"]')
    li[4].click()
    print('Already Unfollowed')

# %%
visit_page('So Delhi')
follow_unfollow()
# Out:
# Already following
# Already Unfollowed

# %%
Q.5.Like/Unlike posts
Liking the top 30 posts of the ‘dilsefoodie'. Print message if you have already liked it.
Unliking the top 30 posts of the ‘dilsefoodie’. Print message if you have already unliked it.

# %%
def like_unlike_top30():
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC
    wait=WebDriverWait(driver,200)
    import time
    #scrolling till 30 posts are visible:
    for i in range(6):
        currentheight=driver.execute_script('return document.body.scrollHeight')
        driver.execute_script('window.scrollTo(0,arguments[0])',currentheight)
        time.sleep(10)
    #scrolling to the top again:   
    driver.execute_script('window.scrollTo(0,0);')
    
    #extracting the web elements of all the posts to like and unlike:
    lis=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="_aabd _aa8k  _al3l"]')))
    lis=driver.find_elements(By.XPATH,'//div[@class="_aabd _aa8k  _al3l"]')
    
    #liking and unliking all the posts and sharing message accrodingly:
    
    #Note: for better representation we can also make a list of the number of the post that we liked and unliked:
    
    for i in range(30):
        print('Post',str(i+1),":")
        lis[i].click()
        like_button=wait.until(EC.presence_of_element_located((By.XPATH,'//span[@class="_aamw"]')))
        like_button.click()
        print('liked')
        like_button.click()
        print('unliked')
        close_button=driver.find_element(By.XPATH,'//div[@class="x10l6tqk x160vmok x1eu8d0j x1vjfegm"]')
        close_button.click()
        print()

# %%
visit_page('dilsefoodie')

# %%
like_unlike_top30()
# Out:
# Post 1 :
# liked
# unliked
#
# Post 2 :
# liked
# unliked
#
# Post 3 :
# liked
# unliked
#
# Post 4 :
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# /var/folders/9x/4xp41zzn79j2sgnc93pkddq80000gn/T/ipykernel_42565/2036198868.py in <module>
# ----> 1 like_unlike_top30()
#
# /var/folders/9x/4xp41zzn79j2sgnc93pkddq80000gn/T/ipykernel_42565/2760005011.py in like_unlike_top30()
#      24         print('Post',str(i+1),":")
#      25         lis[i].click()
# ---> 26         like_button=wait.until(EC.presence_of_element_located((By.XPATH,'//span[@class="_aamw"]')))
#      27         like_button.click()
#      28         print('liked')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/support/wait.py in until(self, method, message)
#      84         while True:
#      85             try:
# ---> 86                 value = method(self._driver)
#      87                 if value:
#      88                     return value
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/support/expected_conditions.py in _predicate(driver)
#      67
#      68     def _predicate(driver):
# ---> 69         return driver.find_element(*locator)
#      70
#      71     return _predicate
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     829             value = f'[name="{value}"]'
#     830
# --> 831         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     832
#     833     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=114.0.5735.90)
# Stacktrace:
# 0   chromedriver                        0x00000001028fff48 chromedriver + 4226888
# 1   chromedriver                        0x00000001028f84f4 chromedriver + 4195572
# 2   chromedriver                        0x000000010253cd68 chromedriver + 281960
# 3   chromedriver                        0x0000000102516ef8 chromedriver + 126712
# 4   chromedriver                        0x000000010259be88 chromedriver + 671368
# 5   chromedriver                        0x00000001025ae45c chromedriver + 746588
# 6   chromedriver                        0x000000010256bf1c chromedriver + 474908
# 7   chromedriver                        0x000000010256cef4 chromedriver + 478964
# 8   chromedriver                        0x00000001028c159c chromedriver + 3970460
# 9   chromedriver                        0x00000001028c56f0 chromedriver + 3987184
# 10  chromedriver                        0x00000001028cb5b4 chromedriver + 4011444
# 11  chromedriver                        0x00000001028c62fc chromedriver + 3990268
# 12  chromedriver                        0x000000010289e1c0 chromedriver + 3826112
# 13  chromedriver                        0x00000001028e2088 chromedriver + 4104328
# 14  chromedriver                        0x00000001028e21e0 chromedriver + 4104672
# 15  chromedriver                        0x00000001028f1f28 chromedriver + 4169512
# 16  libsystem_pthread.dylib             0x0000000196ebc26c _pthread_start + 148
# 17  libsystem_pthread.dylib             0x0000000196eb708c thread_start + 8

# %%
Q.6.Extract list of followers
Extract the usernames of the first 500 followers of ‘foodtalkindia’ and ‘sodelhi’.
Now print all the followers of “foodtalkindia” that you are following but those who don’t follow you.

# %%
def extract_followers():
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC
    wait=WebDriverWait(driver,100)
    import time
    
    #clicking on the followers button
    l=wait.until(EC.presence_of_element_located((By.XPATH,'//ul[@class="x78zum5 x1q0g3np xieb3on"]/li')))
    li=driver.find_elements(By.XPATH,'//ul[@class="x78zum5 x1q0g3np xieb3on"]/li')
    li[1].click()
    
    #scrolling till we can extract the first 500 names:
    
    scroll=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="_aano"]')))
    scroll.click()
    for i in range(120):
        driver.execute_script('arguments[0].scrollTop = arguments[0].scrollTop + arguments[0].offsetHeight;',scroll)
        time.sleep(1)
        
    #extracting the list of 500 followers:    
    follower_list=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="x9f619 xjbqb8w x1rg5ohu x168nmei x13lgxp2 x5pf9jr xo71vjh x1n2onr6 x1plvlek xryxfnj x1c4vz4f x2lah0s x1q0g3np xqjyukv x6s0dn4 x1oa3qoh x1nhvcw1"]')))
    follower_list=driver.find_elements(By.XPATH,'//div[@class="x9f619 xjbqb8w x1rg5ohu x168nmei x13lgxp2 x5pf9jr xo71vjh x1n2onr6 x1plvlek xryxfnj x1c4vz4f x2lah0s x1q0g3np xqjyukv x6s0dn4 x1oa3qoh x1nhvcw1"]')
    count=0
    for i in follower_list:
        if count==500:
            break
        print(count+1,i.text)
        count+=1

# %%
visit_page('foodtalkindia')
extract_followers()
#please note that "foodtalkindia" has hidden the information of followers and limited it to 49 followers only.
# Out:
# 1 _universe_9_9_9
# 2 sandraperez3642792
# 3 sagar_0004
# 4 aarif_pathan_34
# 5 vickyrautela_official
# 6 anujzo
# 7 aashusairwa
# 8 abverma8
# 9 ar.or.a
# 10 adityakhatrii
# 11 akash__571
# 12 lakshminarayn23
# 13 ashiyasinha
# 14 bharatgoyal9844
# 15 _.bitesandsights._
# 16 cameronhejing
# 17 coldbloodevents
# 18 deepaksinh.solanki
# 19 foodies_apkeliye_kuch_khas
# 20 divyanshu98
# 21 froodfunofficial
# 22 hillstationciders
# 23 jaypalrawat41
# 24 smit_8918
# 25 lomesh.mahajan
# 26 makayla.rose.isaac
# 27 mib7250
# 28 mediaconnect.pr
# 29 chetri___m
# 30 nikki.d.somani
# 31 muhammad_mh_topu_100
# 32 omkar__free__fire
# 33 pickmefortravel
# 34 prathamesh2002__
# 35 priyankakapoor_official
# 36 radhegovindinternational
# 37 ripudaman_10
# 38 khyati_sharma_0098
# 39 sarahs_gulabjamun
# 40 someplacemanali
# 41 sonaliitandon
# 42 drsudhakardsp
# 43 suki_sweet__
# 44 tak.ang.0213
# 45 oelnurav
# 46 singhanchal
# 47 durmietch
# 48 muskanbhallaaa
# 49 __rk__krishna__
# 50 sakshii_sharma_05

# %%
visit_page('So Delhi')
extract_followers()
# Out:
# 1 abhijeet3jan
# 2 pallavi.bhardwaj.37
# 3 aashu.dixit.9279
# 4 im_shyogesh
# 5 khatoon_sumaiya
# 6 lakshaymalhotra062
# 7 _abhishekpahuja_
# 8 islamdaniya
# 9 depak007dk
# 10 naaz_khan_1431
# 11 tripti_mittal_26
# 12 gstarwedding
# 13 _sakshi.aggarwal
# 14 apoorva_sarangi
# 15 khosla3558
# 16 zainabmasroor8484
# 17 raakhi.sharma
# 18 vikkas96
# 19 nelsonchongola
# 20 on_13jan
# 21 _01aakriti
# 22 aerry654
# 23 yuganki.kush
# 24 thak.ursahab9651
# 25 _nvneeet
# 26 pari1607
# 27 vibrationsinlife
# 28 priyaj174
# 29 51smartyrohit
# 30 sanatanibala20221405
# 31 imran78368115032023
# 32 ravidhaka.rd
# 33 kritikajerath
# 34 that_therapist_in_a_white_tee
# 35 sonika._.gupta
# 36 mriksha_n
# 37 what_he_explored
# 38 rohityadav66244
# 39 aman.kumar290592
# 40 sadhana.tripathi.146
# 41 ashokaggarwal54
# 42 solankimahima1418
# 43 kirti_____4311
# 44 kujurparboti
# 45 ___harpreet19___
# 46 preetitrika
# 47 adarsh.aaron
# 48 arjun.4060
# 49 makeupbyiramfatma
# 50 g24111984
# 51 meghaarya1
# 52 _jindal_muskan
# 53 anchal_v07
# 54 _vandana_maurya
# 55 shaleni_singh
# 56 rkhverma
# 57 rakhee_2001
# 58 tarunn_.x
# 59 ajaybhagora07
# 60 komalanish
# 61 dr.kirtitripathi__
# 62 prakash.shah111
# 63 _afshaakhan_
# 64 truly_tarot_by_priyanka_khanna
# 65 agrwlsaksham
# 66 jain_himani
# 67 alongwithadarsh
# 68 anushka_bh98
# 69 priyaagarwal797
# 70 gurpreetsingh_0305
# 71 bhawnagandhi91
# 72 flyingasbestos
# 73 amerfort_sheeshmahal
# 74 kundan.jpeg
# 75 sharmaomanju
# 76 homedecoration2.0
# 77 anmaull
# 78 vindhyaraj98
# 79 yatiii_xx
# 80 ratan_._pandit
# 81 mohitmeans_321
# 82 soumyabandi
# 83 annu_mauryaa
# 84 walia.sachin3898
# 85 the_oinky_oink
# 86 gaurayushi
# 87 bisma_khursheed
# 88 shraiyatkapoor
# 89 rathod3215
# 90 parthyadav3105
# 91 20_ananya_08
# 92 usha.bharti.9889
# 93 iamdeekshasharma
# 94 _sheena.bhatia_
# 95 garimagupta1987
# 96 rubyfood.purpose
# 97 nitinsheoran18
# 98 sonia.chana.1460
# 99 pradeep.0597
# 100 snapson.ig
# 101 ria_gulati30
# 102 rawshni_ali_2.0
# 103 ruchimadan18
# 104 __meenu_09
# 105 anshika.aggarwal.98
# 106 xdkrishan
# 107 ms_bollywood5
# 108 mr_sujalkohli26
# 109 poonamchouhan3
# 110 soulful_smile
# 111 writers.pook
# 112 ethyldude
# 113 siddharthpatil07
# 114 tanesha_kalra
# 115 jaiswal.12sachin
# 116 rukmanidubey
# 117 jyoti.khandelwal04
# 118 pvtvidz
# 119 sk_sahu_07
# 120 ankitaagarwal1076
# 121 neerupuri84
# 122 pintu.gujjar28
# 123 sureshkohli639
# 124 nikhilbhushan1
# 125 shrishtisingh9153
# 126 sakshi_jain_1612
# 127 ashok.m.sood
# 128 tenn.ischampion123
# 129 ___prashant_mishra___
# 130 poojapooja1367
# 131 itsnitin.ihm
# 132 iampalaksammi
# 133 praphul.das
# 134 bansalji_1996
# 135 astrolit.me
# 136 muskaan_dreams
# 137 mis_invisiblestring
# 138 setiaraashi
# 139 sarvadamanjeweler
# 140 vrindapankhi03
# 141 _marketing.max_
# 142 sharma_kavya2512
# 143 thenevergiveupboyvijay
# 144 aryanisha04
# 145 rishabhpanchal__
# 146 khushbugupta9899
# 147 food_blogger2002
# 148 bharti_kashyap864
# 149 nishul25
# 150 preeti_dancer_20
# 151 iamankit.aggarwal
# 152 _sourav_1424
# 153 shailesh_dewasi_dhansa
# 154 rujuta.chavare
# 155 _diiivvv.yyyaaa
# 156 _someshmishra_
# 157 goyalsneha_2005.sg
# 158 sonalika2790
# 159 cashewwewew
# 160 fashionstreetindore
# 161 btwiamkartik
# 162 ashnnab20
# 163 rukhsarkhan24x365
# 164 nupur_mithu
# 165 sujitsky
# 166 shivangi5899
# 167 12.preets
# 168 nidhikaushik2
# 169 adanneadams
# 170 shahzad.haseen
# 171 mohd.sakib.9615
# 172 rinniegeorge
# 173 aabidkhanaabidkhan013
# 174 himanshu_ash
# 175 _raghav_9896
# 176 zilar_official
# 177 imdivyanshgupta
# 178 fuzii______
# 179 queen054676
# 180 sonu_df143
# 181 arpitdwivedi22
# 182 kulpreet466
# 183 ekta.singhh_
# 184 __vaniii.poudwal_
# 185 27______cheeku
# 186 dattamrita
# 187 akankshasiingh23
# 188 _bunnytaneja
# 189 bhumiiii_x
# 190 treasures.of_nature
# 191 swatihans0787
# 192 divyerajsharma
# 193 sumanjaiswal151
# 194 amit.dp80
# 195 kalyan.who
# 196 sargunn.marwaha
# 197 miss._.qureshi1
# 198 that_minimalist__girl
# 199 aditisharma88638
# 200 sachingarg2491
# 201 poonamjindal1011
# 202 trizaafordell
# 203 i_mrashi
# 204 reelhit_
# 205 rita.bharti.142240
# 206 neerajneeraj1807
# 207 nita.patel141193
# 208 ritu0802jain
# 209 bj_bhawana
# 210 ur_yummy_22
# 211 ishubansal10
# 212 luckyagarwal753
# 213 _seeddhee
# 214 mainksantt
# 215 mohitmittal15
# 216 ms.anjali_0795
# 217 _ishikkaaa29_
# 218 yadavhu_
# 219 nikhilsht
# 220 priya1602bansal
# 221 sh_arad315
# 222 stub_sid
# 223 _.ojasvisarwaiya._
# 224 hood_hopper_mehak
# 225 _official_fayyaz_lal_
# 226 sanjeev19502021
# 227 akshitshokeen
# 228 chandigarhtales_
# 229 kabiransari07
# 230 sahil_mittal_6095
# 231 abhimanyu_dubey_k
# 232 sriya_vk
# 233 aslamqais
# 234 jain.alkavj
# 235 neeshu4966
# 236 that_duchennesmilegirl
# 237 prashaantt16
# 238 rahema_naqvii
# 239 gaur9033
# 240 poonam.soni.33234
# 241 surirajani77
# 242 shifan069
# 243 aggarwaldishank
# 244 miss_makker
# 245 dessert_360_degrees
# 246 shivinder0600
# 247 anupriyasharma595
# 248 bhr_t_15
# 249 _meenakshipahwa
# 250 namanp09
# 251 pri_bhar89
# 252 shivani_yadav118
# 253 harsha_palwar
# 254 __peachyvibe_
# 255 uusha2112
# 256 smritisingh.shahi
# 257 devina_sheetal
# 258 sudhirajphutela00014
# 259 k.tomar.5245
# 260 _sanowarrr
# 261 its_abdullah79
# 262 shorya_1996
# 263 harshal_s_wankhede
# 264 kkanchan27
# 265 soindiaofficial
# 266 been_there_done_that_26
# 267 kya.tapleek.hai.aapke
# 268 amymulz
# 269 vidhi_chandela
# 270 sheawarnes
# 271 kousar635
# 272 mini.varghese.9469
# 273 reenaroy2055
# 274 mesmericmahima
# 275 jyoti_lalit_khurana
# 276 offbeat_journeys
# 277 theclimbingwolf
# 278 madhuri_bhadauriya_
# 279 alkaseth9
# 280 mahi3535
# 281 nitikalangeh
# 282 arsi2311
# 283 ashiyasinha19
# 284 shivangkas0186
# 285 khushboodevgan0427
# 286 talha_0504
# 287 alwyzzriya
# 288 tanisha_mahrolia_
# 289 rekhamavi732020
# 290 sanyogitajain
# 291 puja_havbd
# 292 manvi.ithakur
# 293 shilpitiwari254
# 294 tomersoumya
# 295 kunwergogia
# 296 vanshhh____
# 297 shaifalisethi
# 298 houseofsmoke6
# 299 anjum.sabahat17
# 300 sacred.saurabh
# 301 shwetaarora736
# 302 rini_khanna_1973
# 303 ishu.khan8120006
# 304 hsharma29
# 305 shreya_trouvaille
# 306 foodiegoli
# 307 archana__classy
# 308 charulalhoon
# 309 aakash_5801
# 310 kirti_bansal96
# 311 bhawna88653
# 312 kanikabhatia4
# 313 akshaychaudhary_93
# 314 s.shinchan.n
# 315 nancy.jai_bhankhar
# 316 rishita.garg7621
# 317 cashaurya11
# 318 sweksha.gg
# 319 wander.r.r
# 320 surbhi.arora257
# 321 arushij08
# 322 driftwood.81
# 323 karannzzz
# 324 shweta914
# 325 _orgasmiii_
# 326 pilescare_by_vaidmohansingh
# 327 zxleaie
# 328 fallen_bruce
# 329 priyanshaaverma_
# 330 ruchi1306
# 331 maheshjaiswal0017
# 332 madnidss
# 333 punyata.jain
# 334 shiv61184
# 335 __aayushi19
# 336 kusumkain
# 337 vansshhh_29
# 338 vanshikashrma._
# 339 suraj_mehta_official
# 340 samarnigar
# 341 jatinsharmagaya
# 342 sanskratijain3
# 343 priyanka.sh81
# 344 kitkattpvt
# 345 anjaliqueen38
# 346 kripakansha_
# 347 divya_nagpal17
# 348 n.awasthi890
# 349 naved_malik45
# 350 yogita.parvesh.rathi
# 351 tavishidarbari
# 352 viren_4117
# 353 tarusrivastava
# 354 shiprapatnaik
# 355 piku.manish
# 356 trendystation__
# 357 renug297
# 358 allenn_singh
# 359 oye_maaz_013
# 360 unzayaseen
# 361 parveenkhandelia
# 362 dr.deepakchhikara
# 363 yuvi.chawla22
# 364 gurgaonking2023
# 365 bhumika_khanna02
# 366 alcatraz_141
# 367 manisha_multani27
# 368 soul.2589
# 369 adnanq369
# 370 mohammadbilalofficial1
# 371 hiimanshu7_
# 372 beingme_suhair
# 373 diya_barnwal
# 374 pankaj_narula1
# 375 rishi_vandit
# 376 ranikadiandhaka
# 377 hemanshikha04
# 378 framing_delhi
# 379 arti.trivedi2020
# 380 _____abhagupta
# 381 _riyabansal256
# 382 i_ishitaa1
# 383 bakshishmarwah
# 384 yuktadahiya_15
# 385 sak_shi0
# 386 jaineshna
# 387 jiya420q
# 388 priyah._sharma
# 389 yogeshrathore25
# 390 annkitrohatgi
# 391 gry_ffin.dor
# 392 macsingh82
# 393 rashmi.duggal.90
# 394 tarunjain168
# 395 pooja_0518
# 396 pranayjha1989
# 397 barkha.singhal.50
# 398 royal_rollsroyce
# 399 _sangeetasaini_
# 400 himiashu
# 401 leenapritwani
# 402 divanshuchopra
# 403 itz_reshmi_223
# 404 naman834
# 405 himanshi.kalyan
# 406 swetapandey521
# 407 seth_ankit
# 408 lohit_ratnani
# 409 ashishbhayanaa
# 410 peace_full_soul_003
# 411 drishti.bajoria
# 412 _absk.l
# 413 dishhaa_01
# 414 sum.am2496
# 415 nishh_at
# 416 aaman_jindal22
# 417 king__.sameer__69s
# 418 anum__shah_
# 419 lock_downgirl
# 420 himalyan_blood_7
# 421 the_goldenn_snitch
# 422 rubybhuviyadav89
# 423 deepikamehlan
# 424 avinesh_singh_
# 425 ishika_kishu143
# 426 nehadubey_09
# 427 _preetiii_01
# 428 maaal._.function
# 429 eshanksabharwal10
# 430 exquisitee_soul_
# 431 sumbloom12
# 432 storiesbykaydee
# 433 chawdarenu
# 434 sh.ivani1203
# 435 vinny_jasuja
# 436 _bharat.jain
# 437 voyager_cobra
# 438 official__chandan__bsty
# 439 swatisnehasingh
# 440 puja_agrawal27
# 441 sonam__chauhan
# 442 rajamansoori733451
# 443 __tanisha__001
# 444 irfzilla
# 445 shubham.sr4
# 446 i.khushiiiiiii
# 447 rajput__akshat
# 448 cheetah_the_indian_cowboy_
# 449 anikaa_1803
# 450 hri_thic_a
# 451 __shrutisingh_
# 452 an_ita4915
# 453 seema__rehman
# 454 raviyoukumar
# 455 romitkr19
# 456 irajatsinghal
# 457 m0nk3fl1p
# 458 harsh_sharma_3007
# 459 vanshika.balani
# 460 punjabnewsscoop
# 461 dishant_chaudhry
# 462 rudragoyal4431
# 463 wonderlustbitex
# 464 nehaohri11
# 465 taruna.anand
# 466 aditi__31
# 467 mitalikumakale
# 468 trueliving6945
# 469 sangita.aero
# 470 rahul_chhawani00
# 471 zsukhbir
# 472 jyotitarik.arora
# 473 anjaleeww
# 474 havucamroll
# 475 rohanshorya
# 476 sreekuttykb
# 477 notwilin_
# 478 kia_sharma3256
# 479 sabinaali78692
# 480 sharma__mayank
# 481 ishaan.gupta
# 482 munjalrachita
# 483 kamleshji_8
# 484 choudhryritu0311
# 485 so.nic9299
# 486 official_____boy___45
# 487 dr_anjum_hasan
# 488 zaman_in_zeal
# 489 khushii_aggarwal
# 490 monica.arora.sapra
# 491 lightroom_shotz
# 492 prabhavbathla
# 493 abhisheknayak421
# 494 shivam_.india
# 495 mehakaggarwal_08
# 496 rudesupreme
# 497 dollybhatia5
# 498 riturajpal18
# 499 _pujashokeen_
# 500 pyaragrugaon

# %%
def extract_mutual_unsubscribed_followers():
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC
    wait=WebDriverWait(driver,500)
    import time 
    #finding a clicking the button ('followed by') for finding mutual followers of the page:
    mutual=wait.until(EC.presence_of_element_located((By.XPATH,'//span[@class="_aaaj"]')))
    mutual=driver.find_element(By.XPATH,'//span[@class="_aaaj"]')
    mutual.click()
    
    #clicking on see all followers in the pop-up:
    all_followers=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh xw7yly9 xktsk01 x1yztbdb x1d52u69 x1n2onr6 x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1"]')))
    all_followers.click()
    
   
    #ran the loop for 20 times by purpose as the number of followers is high for the given page and an infinite loop 
    #would take a lot of time in developing and testing the code. In a more ttechnical approach i would run an infinite
    #loop till the scrolling ends using NoSuchElementException and using 'try' and 'except'.
    #scrolling in the pop-up list:
    scroll=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="_aano"]')))
    for i in range(20):
        driver.execute_script(
            'arguments[0].scrollTop = arguments[0].scrollTop + arguments[0].offsetHeight;', 
          scroll)
        time.sleep(1)
    
    #finding list of followers of the page and text within it:
    follower_lis=driver.find_elements(By.XPATH,'//div[@class="x1i10hfl x1qjc9v5 xjbqb8w xjqpnuy xa49m3k xqeqjp1 x2hbi6w x13fuv20 xu3j5b3 x1q0q8m5 x26u7qi x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xdl72j9 x2lah0s xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r x2lwn1j xeuugli xexx8yu x4uap5 x18d9i69 xkhd6sd x1n2onr6 x16tdsg8 x1hl2dhg xggy1nq x1ja2u2z x1t137rt x1q0g3np x87ps6o x1lku1pv x1a2a7pz xh8yej3 x193iq5w x1lliihq x1dm5mii x16mil14 xiojian x1yutycm"]')
   
    #finding only the name of followers of the page
    name_lis=driver.find_elements(By.XPATH,'//div[@class="x1i10hfl x1qjc9v5 xjbqb8w xjqpnuy xa49m3k xqeqjp1 x2hbi6w x13fuv20 xu3j5b3 x1q0q8m5 x26u7qi x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xdl72j9 x2lah0s xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r x2lwn1j xeuugli xexx8yu x4uap5 x18d9i69 xkhd6sd x1n2onr6 x16tdsg8 x1hl2dhg xggy1nq x1ja2u2z x1t137rt x1q0g3np x87ps6o x1lku1pv x1a2a7pz xh8yej3 x193iq5w x1lliihq x1dm5mii x16mil14 xiojian x1yutycm"]//div[@class="x9f619 xjbqb8w x1rg5ohu x168nmei x13lgxp2 x5pf9jr xo71vjh x1n2onr6 x1plvlek xryxfnj x1c4vz4f x2lah0s x1q0g3np xqjyukv x6s0dn4 x1oa3qoh x1nhvcw1"]')
    
    
    #saving the result in a list as the web elements wont be accessible once the page refreshes to a new page
    names=[]
    for i in range(len(follower_lis)):
        if 'Following' in follower_lis[i].text:
            if 'Verified' in name_lis[i].text:
                names.append(name_lis[i].text.split()[0])
            else:
                names.append(name_lis[i].text)
            
    
    
    
    #opening web page of every follower that i am following and checking if they follow me back by checking their 
    #'following' list,where my name would appear at the top if they follow me, else not:
    for j in names:
        string='https://www.instagram.com/'+j+'/following/'
        driver.get(string)
        name=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="x1i10hfl x1qjc9v5 xjbqb8w xjqpnuy xa49m3k xqeqjp1 x2hbi6w x13fuv20 xu3j5b3 x1q0q8m5 x26u7qi x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xdl72j9 x2lah0s xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r x2lwn1j xeuugli xexx8yu x4uap5 x18d9i69 xkhd6sd x1n2onr6 x16tdsg8 x1hl2dhg xggy1nq x1ja2u2z x1t137rt x1q0g3np x87ps6o x1lku1pv x1a2a7pz xh8yej3 x193iq5w x1lliihq x1dm5mii x16mil14 xiojian x1yutycm"]')))
        if 'saptarshighosh91' not in name.text:
            print(j)

# %%
visit_page('foodtalkindia')

# %%
extract_mutual_unsubscribed_followers()
# Out:
# bartisans.in
# ranveer.brar

# %% [markdown]
# Q.7. Check the story of ‘coding.ninjas’. Consider the following Scenarios and print error messages accordingly -
# If You have already seen the story.
# Or The user has no story.
# Or View the story if not yet seen.

# %%
def story_status():
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC
    from selenium.common.exceptions import NoSuchElementException
    
    
   #THE CANVAS TAG SHOWS WIDTH AS 168 IF STORY IS NOT SEEN AND 166 IF ITS SEEN:
    try:
        canvas_size=driver.find_element(By.XPATH,'//canvas[@class="_aarh"]')
        li=canvas_size.get_attribute('style').split(';')
        if '168px' in li[3]:
            print('View the story')
            
        else:
            print('You have already seen the story')
    
    #IF CANVAS TAG IS NOT PRESENT IN THE HTML SCRIPT,IT MEANS THERES NO STORY
    except NoSuchElementException:
        print('The user has no story')

# %%
visit_page('coding.ninjas')
story_status()
# Out:
# You have already seen the story

# %%
story_status()
# Out:
# View the story

# %% [markdown]
# Q.!. Now your friend has followed a lot of different food bloggers, he needs to analyse the habits of these bloggers.
#
# From the list of instagram handles you obtained when you searched ‘food’ in previous project. Open the first 10 handles and find the top 5 which have the highest number of followers
#
# Now Find the number of posts these handles have done in the previous 3 days.
#
# Depict this information using a suitable graph.

# %%
def search_top_5(keyword):
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC
    wait=WebDriverWait(driver,500)
    
    #Fetching the search button and clicking on it:
    search=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="x1n2onr6"]//div[@class="_aacl _aacp _aacu _aacx _aada"]')))
    search.click()
    
    #Entering keyword in search box:
    search_box=wait.until(EC.presence_of_element_located((By.XPATH,'//input[@placeholder="Search"]')))
    search_box.send_keys(keyword)
    
    #Extracting list of all suggestions:
    li=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@role="none"]//div[@class="x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1uhb9sk x1plvlek xryxfnj x1iyjqo2 x2lwn1j xeuugli xdt5ytf xqjyukv x1cy8zhl x1oa3qoh x1nhvcw1"]')))
    lis=driver.find_elements(By.XPATH,'//div[@role="none"]//div[@class="x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1uhb9sk x1plvlek xryxfnj x1iyjqo2 x2lwn1j xeuugli xdt5ytf xqjyukv x1cy8zhl x1oa3qoh x1nhvcw1"]')
    names=[]
    for i in range(0,10):
        li=lis[i].text.split()
        names.append(li[0])
    print(names)
    
    #making a dictionary of the instagram handles and the number of their followers:
    dic={}
    for i in names:
        string='https://www.instagram.com/'+i+'/'
        driver.get(string)
        followers_element=wait.until(EC.presence_of_element_located((By.XPATH,'//span[@class="_ac2a"]')))
        follower_lis=driver.find_elements(By.XPATH,'//span[@class="_ac2a"]')
        print(follower_lis[1].text)
        num=follower_lis[1].get_attribute('title')
        num=int(num.replace(',',''))
        dic[i]=num
    print(dic)
    
    
    #sorting the dictionary based on number of followers:
    
    sorted_dic={}
    for w in sorted(dic,key=dic.get,reverse=True):
        sorted_dic[w]=dic[w]

        
    
    return sorted_dic

# %%
#from the sorted dictionary I have seperated the list of list of instagram hand;es and respective folowers:
sorted_dic=search_top_5('food')
top_5=[]
followers=[]
count=0
print(sorted_dic)
for i in sorted_dic:
    
    if count==5:
        break
    top_5.append(i)
    followers.append(sorted_dic[i])
    count+=1
print(top_5)
# Out:
# ['foodie_incarnate', 'dilsefoodie', 'foodtalkindia', 'food.darzee', 'adis_food_voyage', 'the_bong_gastronomist', 'food', 'foodconnectindia', 'yourfoodlab', 'delhifoodie']
# 1.5M
# 1.1M
# 309K
# 216K
# 126K
# 129K
# 182K
# 62K
# 2.7M
# 12.1K
# {'foodie_incarnate': 1531468, 'dilsefoodie': 1106162, 'foodtalkindia': 309771, 'food.darzee': 216366, 'adis_food_voyage': 126530, 'the_bong_gastronomist': 129594, 'food': 182771, 'foodconnectindia': 62059, 'yourfoodlab': 2705384, 'delhifoodie': 12111}
# {'yourfoodlab': 2705384, 'foodie_incarnate': 1531468, 'dilsefoodie': 1106162, 'foodtalkindia': 309771, 'food.darzee': 216366, 'food': 182771, 'the_bong_gastronomist': 129594, 'adis_food_voyage': 126530, 'foodconnectindia': 62059, 'delhifoodie': 12111}
# ['yourfoodlab', 'foodie_incarnate', 'dilsefoodie', 'foodtalkindia', 'food.darzee', 'food', 'the_bong_gastronomist', 'adis_food_voyage', 'foodconnectindia', 'delhifoodie']

# %%
top_5=top_5[:5]
followers=followers[:5]
top_5,followers
# Out:
# (['yourfoodlab',
#   'foodie_incarnate',
#   'dilsefoodie',
#   'foodtalkindia',
#   'food.darzee'],
#  [2705384, 1531468, 1106162, 309771, 216366])

# %% [markdown]
# Q.2 Your friend also needs a list of hashtags that he should use in his posts.
# Open the 5 handles you obtained in the last question, and scrape the content of the first 10 posts of each handle.
#
# Prepare a list of all words used in all the scraped posts and calculate the frequency of each word.
#
# Create a csv file with two columns : the word and its frequency
#
# Now, find the hashtags that were most popular among these bloggers
#
# Plot a Pie Chart of the top 5 hashtags obtained and the number of times they were used by these bloggers in the scraped posts.

# %%
def posts_3_days_ago(lis):
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC
    wait=WebDriverWait(driver,500)
    import time
    
    
    post_dic={}
    
    
    for i in lis:
        #visiting every page seperately and checking the posting date of every post:
        string='https://www.instagram.com/'+i
        driver.get(string)
        wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="_aabd _aa8k  _al3l"]')))
        post_lis=driver.find_elements(By.XPATH,'//div[@class="_aabd _aa8k  _al3l"]')
        count=0
        total_like=0
        for ele in post_lis:
            ele.click()
            #fetching data from the web element having information of posting time:
            time=wait.until(EC.presence_of_element_located((By.XPATH,'//time[@class="_aaqe"]')))
            print(time.text)
            if 'SECOND' in time.text:
                count+=1
            if 'MINUTE' in time.text:
                count+=1
            if 'HOUR' in time.text:
                count+=1
            if 'DAY' in time.text:
                if int(time.text.split()[0])<4:
                    count+=1
                else:
                    break
            print(count)
            
            close_button=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="x10l6tqk x160vmok x1eu8d0j x1vjfegm"]')))
            close_button=driver.find_element(By.XPATH,'//div[@class="x10l6tqk x160vmok x1eu8d0j x1vjfegm"]')
            close_button.click()
        
        #adding elements to a dicitionary along with frequency of posts:  
        post_dic[i]=count
        print(post_dic)
    return post_dic

# %%
dic=posts_3_days_ago(top_5)
# Out:
# 1 DAY AGO
# 1
# 2 DAYS AGO
# 2
# 4 DAYS AGO
# {'yourfoodlab': 2}
# 1 DAY AGO
# 1
# 2 DAYS AGO
# 2
# 5 DAYS AGO
# {'yourfoodlab': 2, 'foodie_incarnate': 2}
# 15 HOURS AGO
# 1
# 23 HOURS AGO
# 2
# 1 DAY AGO
# 3
# 3 DAYS AGO
# 4
# 3 DAYS AGO
# 5
# 5 DAYS AGO
# {'yourfoodlab': 2, 'foodie_incarnate': 2, 'dilsefoodie': 5}
# 17 HOURS AGO
# 1
# 1 DAY AGO
# 2
# 1 DAY AGO
# 3
# 2 DAYS AGO
# 4
# 3 DAYS AGO
# 5
# 5 DAYS AGO
# {'yourfoodlab': 2, 'foodie_incarnate': 2, 'dilsefoodie': 5, 'foodtalkindia': 5}
# 17 HOURS AGO
# 1
# 1 DAY AGO
# 2
# 2 DAYS AGO
# 3
# 3 DAYS AGO
# 4
# 4 DAYS AGO
# {'yourfoodlab': 2, 'foodie_incarnate': 2, 'dilsefoodie': 5, 'foodtalkindia': 5, 'food.darzee': 4}

# %%
#plotting bar chart on instagram handle vs No. of posts:
import matplotlib.pyplot as plt

x=[]
y=[]

#plotting instagram handles along X axis and no. of posts along Y axis:
for ele in dic:
    x.append(ele)
    y.append(dic[ele])
plt.bar(x,y,edgecolor="black",width=0.4,color="red",alpha=0.5)
plt.xlabel("Instagram Handle")
plt.ylabel("No.of Post in 3 days")
plt.title("Top Handles vs No.of Posts", color="green")
plt.show()

# %%
#Note that this function gives both list of words and average likes in a go, making the code more efficient:


def extract_words_and_likes_posts(lis):
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.wait import WebDriverWait
    from selenium.webdriver.support import expected_conditions as EC


    
    wait=WebDriverWait(driver,500)
    
    #Initiating an empty list for list of words and average_like:
    list_of_words=[]
    average_like=[]
    
    
    for i in lis:
        #visiting every page and fetching the likes and list of words:
        string='https://www.instagram.com/'+i
        driver.get(string)
            
        
        #list of posts:
        wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="_aabd _aa8k  _al3l"]')))
        post_lis=driver.find_elements(By.XPATH,'//div[@class="_aabd _aa8k  _al3l"]')
        post_lis=post_lis[:10]
        
        #initiating ototal_likes count for every page:
        total_like=0
        
        
        #fetching words and likes from every post:
        for ele in post_lis:


            ele.click()
            
            #accessing heading web element to get the text:
            heading=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="_a9zs"]')))

            li=heading.text.split('.')
            for i in li:
                sub_li=i.split()
                for j in sub_li:
                    list_of_words.append(j)
            
            #data of likes:
            like=driver.find_element(By.XPATH,'//span[@class="x193iq5w xeuugli x1fj9vlw x13faqbe x1vvkbs xt0psk2 x1i0vuye xvs91rp x1s688f x5n08af x10wh9bi x1wdrske x8viiok x18hxmgj"]')
            lik=like.text
            print(lik)
            
            
            #refining the data of likes into suitable integer format:
            if len(lik)==1 and'others' not in lik:
                total_like+=0
            if ',' in lik:
                    lik=lik.replace(',','')

            if len(lik.split())>1 and 'others' in lik:
                total_like+=int(lik.split()[-2])+1
            if len(lik.split())>1 and 'others' not in lik:
                total_like+=int(lik.split()[-2])
            close_button=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="x10l6tqk x160vmok x1eu8d0j x1vjfegm"]')))
            close_button=driver.find_element(By.XPATH,'//div[@class="x10l6tqk x160vmok x1eu8d0j x1vjfegm"]')
            close_button.click()
        print(total_like)        
        
        

            
        average_like.append(total_like//10)
        print('average',average_like)
    
    
    #returning the average likes list and list of words:
    return average_like,list_of_words

# %%
likes,words=extract_words_and_likes_posts(top_5)
# Out:
# 10,580 likes
# 28,403 likes
# 15,246 likes
# 15,229 likes
# 53,338 likes
# 68,055 likes
# 35,670 likes
# 145,681 likes
# 150,984 others
# 43,639 likes
# 566826
# average [56682]
# 38,906 others
# 5,920 likes
# 6,842 likes
# 4,056 likes
# 19,367 likes
# 10,011 likes
# 6,780 likes
# 3,858 likes
# 6,740 likes
# 4,796 likes
# 107277
# average [56682, 10727]
# 198 likes
# 255 likes
# 359 likes
# 154 likes
# 220 likes
# 207 likes
# 359 likes
# 138 likes
# 101 likes
# 143 likes
# 2134
# average [56682, 10727, 213]
# 19 likes
# 95 likes
# 104 likes
# 429 likes
# 51 likes
# 57 likes
# 1,038 likes
# 57 likes
# 912 likes
# 218 likes
# 2980
# average [56682, 10727, 213, 298]
# chrissbeen
# salado__in
# boredbeast77
# harp.er8357
# sxkonvz6k
# akealastvalle
# sxkonvz6k
# harp.er8357
# harp.er8357
# sxkonvz6k
# 0
# average [56682, 10727, 213, 298, 0]

# %% [markdown]
# Exporting words data to CSV file:

# %%
#exporting data to CSV file:

import pandas as pd
from collections import Counter
c1=dict(Counter(words))

#creating a hashtags dictionary based on frequency:

hashtags={}
for w in sorted(c1,key=c1.get,reverse=True):
    if '#' in w:
        hashtags[w]=c1[w]
_2d_list=[]

#making a dataframe of words and frequency:
for i in c1:
    _2d_list.append([i,c1[i]])

dataframe=pd.DataFrame(_2d_list)

#importing to a CSV file:
dataframe.columns=['words','frequency']
dataframe.to_csv('word-frequency_trial.csv')

# %% [markdown]
# Top 5 Hashtags plotted on pie chart:

# %%
#Plotting pie chart of top 5 hashtags 
import pandas as pd
import matplotlib.pyplot as plt

from collections import Counter

#making a sorted dictiionary of hashtags:
c1=dict(Counter(words))
hashtags={}
for w in sorted(c1,key=c1.get,reverse=True):
    if '#' in w:
        hashtags[w]=c1[w]
count=0

#graph plotting steps from hashtag dictionary:
x=[]
y=[]
for i in hashtags:
    if count==5:
        break
    x.append(i)
    y.append(hashtags[i])
    count+=1
plt.pie(y,labels=x,autopct="%.2f%%")
plt.show()

# %%
followers
# Out:
# [1514998, 1103137, 309789, 216041, 182726]

# %%
likes
# Out:
# [0]

# %% [markdown]
# Q.5. You need to also calculate average followers : likes ratio for the obtained handles.
# Followers : Likes ratio is calculated as follows:
#
# Find out the likes of the top 10 posts of the 5 handles obtained earlier.
#
# Calculate the average likes for a handle.
#
#
# Divide the average likes obtained from the number of followers of the handle to get the average followers:like ratio
# of each handle.
#
# Create a bar graph to depict the above obtained information.

# %%
#the average likes of top 5 handles has been obtained already from the above function,I have used that information here:
import matplotlib.pyplot as plt
followers
likes
x=top_5
y=[]
for j in range(len(likes)):
    if likes[j]==0:
        print('The page of',top_5[j],'has hidden number of likes information and hence it has been taken zero for calculation')
for i in range(5):
    if likes[i]==0:
        y.append(0)
        continue
    else:
        y.append(followers[i]//likes[i])
print(x,y)
plt.bar(x,y,edgecolor="black",width=0.4,color="red",alpha=0.5)
plt.xlabel("Instagram Handle")
plt.ylabel("Average Follower:Likes Ratio")

plt.show()
# Out:
# The page of food has hidden number of likes information and hence it has been taken zero for calculation
# ['foodie_incarnate', 'dilsefoodie', 'foodtalkindia', 'food.darzee', 'food'] [26, 102, 1454, 724, 0]

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import TimeoutException
wait=WebDriverWait(driver,500)
driver.get('https://www.instagram.com/foodie_incarnate/') 
wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="_aabd _aa8k  _al3l"]')))
        
      
        post_lis=driver.find_elements(By.XPATH,'//div[@class="_aabd _aa8k  _al3l"]')
        post_lis=post_lis[:3]
        list_of_words=[]
        total_like=0

        for ele in post_lis:


            ele.click()
            heading=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="_a9zs"]')))

            li=heading.text.split('.')
            for i in li:
                sub_li=i.split()
                for j in sub_li:
                    list_of_words.append(j)

            like=driver.find_element(By.XPATH,'//span[@class="x193iq5w xeuugli x1fj9vlw x13faqbe x1vvkbs xt0psk2 x1i0vuye xvs91rp x1s688f x5n08af x10wh9bi x1wdrske x8viiok x18hxmgj"]')
            lik=like.text
            print(lik)
            if len(lik)==1 and'others' not in lik:
                total_like+=0
            if ',' in lik:
                    lik=lik.replace(',','')

            if len(lik.split())>1 and 'others' in lik:
                total_like+=int(lik.split()[-2])+1
            if len(lik.split())>1 and 'others' not in lik:
                total_like+=int(lik.split()[-2])
            close_button=wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="x10l6tqk x160vmok x1eu8d0j x1vjfegm"]')))
            close_button=driver.find_element(By.XPATH,'//div[@class="x10l6tqk x160vmok x1eu8d0j x1vjfegm"]')
            close_button.click()
        print(total_like)
# Out:
# 8,091 likes
# 24,978 likes
# 14,995 likes
# 48064

# %%
list_of_words
# Out:
# ['Absolutely',
#  'loved',
#  'this',
#  'Pahadi',
#  'Thali',
#  'made',
#  'of',
#  'locally',
#  'sourced',
#  'ingredients',
#  'at',
#  '@pilibhithouseharidwar',
#  '👌🏻👌🏻',
#  '#foodieincarnate',
#  '#foodieincarnaterecommends',
#  '#pilibhithouse',
#  '#haridwar',
#  'This',
#  'is',
#  'how',
#  'Salted',
#  'Peanuts',
#  'are',
#  'made😳😳',
#  'Tag',
#  'your',
#  'chakhna',
#  'lover',
#  'friends🤗🤗',
#  'Watch',
#  'its',
#  'full',
#  'detailed',
#  'video',
#  'on',
#  'my',
#  'YouTube',
#  'channel',
#  'Link',
#  'is',
#  'in',
#  'my',
#  'bio🤗🤗',
#  '#foodieincarnate',
#  '#reelitfeelit',
#  '#reelkarofeelkaro',
#  '#reelsinstagram',
#  '#reels',
#  '#chakna',
#  '#peanut',
#  '#surat',
#  '#gujarat',
#  '#explore',
#  'Tag',
#  'your',
#  'Gujarati',
#  'friend🤗🤗',
#  'Watch',
#  'its',
#  'full',
#  'detailed',
#  'video',
#  'on',
#  'my',
#  'YouTube',
#  'channel',
#  'Link',
#  'is',
#  'in',
#  'my',
#  'bio🤗🤗',
#  '#foodieincarnate',
#  '#reelitfeelit',
#  '#reelkarofeelkaro',
#  '#reelsinstagram',
#  '#reels',
#  '#pizza',
#  '#locho',
#  '#surat',
#  '#gujju',
#  '#explore']

# %%
lik='no1_foodrecipe'
total_like=1
if len(lik.split())==1 and'others' not in lik:
        total_like+=0
total_like
# Out:
# 1

# %%
like=driver.find_element(By.XPATH,'//section[@class="_ae5m _ae5n _ae5o"]')
# Out:
# ''
